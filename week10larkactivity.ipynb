# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("week10.csv")

# %%
df
# Out:
#              ph    Hardness       Solids  Chloramines     Sulfate  \
# 0      8.316766  214.373394  22018.41744     8.059332  356.886136
# 1      9.092223  181.101509  17978.98634     6.546600  310.135738
# 2      5.584087  188.313324  28748.68774     7.544869  326.678363
# 3     10.223862  248.071735  28749.71654     7.513408  393.663395
# 4      8.635849  203.361523  13672.09176     4.563009  303.309771
# ...         ...         ...          ...          ...         ...
# 2006   8.989900  215.047358  15921.41202     6.297312  312.931021
# 2007   6.702547  207.321086  17246.92035     7.708117  304.510230
# 2008  11.491011   94.812545  37188.82602     9.263166  258.930600
# 2009   6.069616  186.659040  26138.78019     7.747547  345.700257
# 2010   4.668102  193.681736  47580.99160     7.166639  359.948574
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 0       363.266516       18.436525       100.341674   4.628771
# ...

# %%
df.isna().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# dtype: int64

# %%
#3. Examine the variables ‘Hardness’, ‘Sulfate’, and ‘Organic_carbon’ and comment on your observations

# %%
df1=df[['Hardness','Sulfate','Organic_carbon']]

# %%
df1.hist(figsize=(10,6))
# Out:
# array([[<AxesSubplot:title={'center':'Hardness'}>,
#         <AxesSubplot:title={'center':'Sulfate'}>],
#        [<AxesSubplot:title={'center':'Organic_carbon'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
#all three are normally distributed

# %%
df1.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# the boxplot shows that they have outliers

# %%
#3)Carry out correlation analysis on the dataset and find the correlation factor between

# %%
corr=df.corr()
plt.subplots(figsize=(15,10))
sns.heatmap(corr,vmin=-2,vmax=1,annot=True,linewidth=.2,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
#there is no significant correlation between the variables

# %%
df2=df[['ph','Chloramines']].corr()

# %%
sns.heatmap(df2,annot=True)
plt.show()

# %% [markdown]
#  they are negatively correated therefore as ph increases chloramines decreases and vice-versa

# %%
df2=df[['ph','Conductivity']].corr()

# %%
sns.heatmap(df2,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# they are positively correated therefore as ph increases conductivity increases and vice-versa
